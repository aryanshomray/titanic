# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#tensorflow
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
#Uploading Data
df=pd.read_csv('train.csv')
dt=pd.read_csv('test.csv')

# %%
#Checking null values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.drop(columns=['Cabin'])
dt=dt.drop(columns=['Cabin'])

# %%
#Converting male to 1 and female to 0
for i in range(df.shape[0]):
    if df.iat[i,4]=='male':
        df.iat[i,4]=1
    else:df.iat[i,4]=0
        
for i in range(dt.shape[0]):
    if dt.iat[i,3]=='male':
        dt.iat[i,3]=1
    else:dt.iat[i,3]=0

# %%
#Removing Nan values for Age
for i in range(df.shape[0]):
    if pd.isna(df.iat[i,5]):
        df.iat[i,5]=df[(df.Sex==df.iat[i,4])&(df.Pclass==df.iat[i,2])].Age.mean()
        
for i in range(dt.shape[0]):
    if pd.isna(dt.iat[i,4]):
        dt.iat[i,4]=dt[(dt.Sex==dt.iat[i,3])&(dt.Pclass==dt.iat[i,1])].Age.mean()

# %%
#Removing Nan in Embarked
for i in range(df.shape[0]):
    if pd.isna(df.iat[i,8]):
        df.iat[i,8]='S'

# %%
#Dropping Fare
df=df.drop(columns=['Fare'])
dt=dt.drop(columns=['Fare'])

# %%
#Converting Embarked into numbers
for i in range(df.shape[0]):
    if df.iat[i,8]=='S':
        df.iat[i,8]=0
    if df.iat[i,8]=='C':
        df.iat[i,8]=1
    if df.iat[i,8]=='Q':
        df.iat[i,8]=2
        
for i in range(dt.shape[0]):
    if dt.iat[i,7]=='S':
        dt.iat[i,7]=0
    if dt.iat[i,7]=='C':
        dt.iat[i,7]=1
    if dt.iat[i,7]=='Q':
        dt.iat[i,7]=2

# %%
#Dropping unnessary fields
df=df.drop(columns=['Ticket','Name'])
dt=dt.drop(columns=['Ticket','Name'])

# %%
#Changing Index
df.index=df.PassengerId
df=df.drop(columns=['PassengerId'])
dt.index=dt.PassengerId
dt=dt.drop(columns=['PassengerId'])

# %%
#Normalizing Age
df.Age=df.Age/10
dt.Age=dt.Age/10

# %%
from tensorflow.keras import layers

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
l0=tf.keras.layers.Dense(20,input_shape=(6,1),activation='relu')
l1=tf.keras.layers.Dense(12,activation='relu')
l2=tf.keras.layers.Dense(2,activation='softmax')

# %%
df
# Out:
#              Survived  Pclass Sex       Age  SibSp  Parch Embarked
# PassengerId
# 1                   0       3   1  2.200000      1      0        0
# 2                   1       1   0  3.800000      1      0        1
# 3                   1       3   0  2.600000      0      0        0
# 4                   1       1   0  3.500000      1      0        0
# 5                   0       3   1  3.500000      0      0        0
# 6                   0       3   1  2.650759      0      0        2
# 7                   0       1   1  5.400000      0      0        0
# 8                   0       3   1  0.200000      3      1        0
# 9                   1       3   0  2.700000      0      2        0
# 10                  1       2   0  1.400000      1      0        1
