# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('train.csv')
dt=pd.read_csv('test.csv')

# %%
print(df.isna().sum())
print('-'*20)
print(dt.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# --------------------
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#fare scatter survival plot
_=plt.plot(df.Fare[df.Survived==1],df.Age[df.Survived==1],marker='.',linestyle='none')
_=plt.plot(df.Fare[df.Survived==0],df.Age[df.Survived==0],marker='.',linestyle='none')
_=plt.xlabel('Fare')
_=plt.ylabel('Survived')
plt.show()

# %%
df=df.drop(columns=['Cabin'])
dt=dt.drop(columns=['Cabin'])

# %% [markdown]
# <p>This shows that the survival depends on the fare</p>

# %%
sns.set()
_=plt.bar(df.Pclass,df.Age,df.Sex)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\python\lib\site-packages\matplotlib\axes\_axes.py in _convert_dx(dx, x0, xconv, convert)
#    2179                 delist = True
# -> 2180             dx = [convert(x0 + ddx) - x for ddx in dx]
#    2181             if delist:
#
# d:\python\lib\site-packages\matplotlib\axes\_axes.py in <listcomp>(.0)
#    2179                 delist = True
# -> 2180             dx = [convert(x0 + ddx) - x for ddx in dx]
#    2181             if delist:
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U21') dtype('<U21') dtype('<U21')
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# d:\python\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1550         try:
# ...

# %%
print(df.isna().sum())
print('-'*20)
print(dt.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64
# --------------------
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Ticket          0
# Fare            1
# Embarked        0
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
p1=plt.bar([0,1,2],)
p2=plt.bar([0,1,2],)
